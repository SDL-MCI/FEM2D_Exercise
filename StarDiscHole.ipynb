# %% [markdown]
# # Disc with Hole
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Load libaries

# %%
import tkinter as tk
import numpy as np
import matplotlib.pyplot as plt
from fjFEM2D_lib import read_ANSYS, plot_mesh, post_proc

# %% [markdown]
# ### Select ANSYS input file

# %%
root = tk.Tk()
root.wm_attributes('-topmost', 1)
root.withdraw()
file_path = tk.filedialog.askopenfilename(title="Select File", filetypes=[("All Files", "*.dat*")])

# %% [markdown]
# ### Parse ANSYS input file

# %%
N, E, BC, matProp, elMat, fex = read_ANSYS(file_path)
plot_mesh(N, E, BC, elMat)

# %% [markdown]
# ## FEMD 2D (Laplace equation)

# %%
u =

# %% [markdown]
# ### Post-processing

# %%
post_proc(N, E, u)
